# %%
import pandas as pd
from datetime import datetime
from sqlalchemy import create_engine, text
import uuid
engine = create_engine('postgresql://postgres:postgres@199.241.139.206:5431/dental_jobs')

df = pd.read_sql_query('select * from source.source_private_practices',con=engine)
# df["compensation"] = ""
# df = df[["job_id", "employer", "state", "location","compensation", "job_type", "days_of_week", "description", "date_posted", "post_link", "source"]]
# df["employer"] = df["employer"].str.strip("Answer:\n")

# # Change if the format is Sep 30, 2023 to 2023-09-30 else leave it as is
# df["date_posted"] = df["date_posted"].apply(lambda x: datetime.strptime(x, '%b %d, %Y').strftime('%Y-%m-%d') if len(x) > 10 else x)

# # Generate uuid that maps to post_link
# df["job_id"] = df["post_link"].apply(lambda x: uuid.uuid3(uuid.NAMESPACE_URL, x))
# # list(df["job_id"].values)
# df["job_id"] = df["job_id"].apply(lambda x: str(x))

# Remove duplicates
df.drop_duplicates(subset=["job_id"], inplace=True)
df.to_sql('source_private_practices', schema="source", con=engine, if_exists='replace', index=False)
# Out:
# 716

# %%
dental_post_path = "/Volumes/Programming/dental_automation/scrape_test/data/dental_post_100523.csv"
dentist_job_path = "/Volumes/Programming/dental_automation/scrape_test/data/dentist_job_cafe_100523.csv"

dental_post = pd.read_csv(dental_post_path)
dental_post["compensation"] = ""
dental_post = dental_post[['job_id', 'employer', 'state', 'location', 'compensation', 'job_type', 'days_of_week', 'description', 'date_posted', 'post_link', 'source']]
dental_post["employer"] = dental_post["employer"].str.strip("Answer:\n")
dental_post["date_posted"] = dental_post["date_posted"].apply(lambda x: datetime.strptime(x, '%b %d, %Y').strftime('%Y-%m-%d') if len(x) > 10 else x)
dental_post["job_id"] = dental_post["post_link"].apply(lambda x: uuid.uuid3(uuid.NAMESPACE_URL, x))
dental_post["job_id"] = dental_post["job_id"].apply(lambda x: str(x))

dentist_job = pd.read_csv(dentist_job_path)
dentist_job["compensation"] = ""
dentist_job = dentist_job[['job_id', 'employer', 'state', 'location', 'compensation', 'job_type', 'days_of_week', 'description', 'date_posted', 'post_link', 'source']]
dentist_job["employer"] = dentist_job["employer"].str.strip("Answer:\n")
dentist_job["date_posted"] = dentist_job["date_posted"].apply(lambda x: datetime.strptime(x, '%b %d, %Y').strftime('%Y-%m-%d') if len(x) > 10 else x)
dentist_job["job_id"] = dentist_job["post_link"].apply(lambda x: uuid.uuid3(uuid.NAMESPACE_URL, x))
dentist_job["job_id"] = dentist_job["job_id"].apply(lambda x: str(x))

# %%
import pandas as pd
from datetime import datetime
from sqlalchemy import create_engine, text
import uuid
engine = create_engine('postgresql://postgres:postgres@199.241.139.206:5431/dental_jobs')
df = pd.read_sql_query('select * from job_postings',con=engine)
df
# Out:
#                                     job_id  \
# 0     cc72ad35-0090-3de4-947b-5f853026c4db
# 1     535fb115-4f8c-38ac-8dea-d92a52fd2175
# 2     48570766-8c30-3cfc-872e-d6348f258b8b
# 3     4633f54c-7dd2-3372-be1b-9d53dd95f1a6
# 4     0c8616a5-354f-37ec-a1ab-0c8331735c25
# ...                                    ...
# 3028  6e07432a-53fd-3ad1-97fc-0e19e439da87
# 3029  acbadd47-304e-305b-8f3a-0da470e44e94
# 3030  dcf7ced6-a49f-36c7-8ef1-b1f79aaadb4e
# 3031  8508bd78-0fda-3955-adab-14b3b21f186c
# 3032  53893e68-7444-3718-86ef-0d587bd520a0
#
#                                            job_title  \
# 0                    Periodontist Wasatch Front Utah
# 1     Dds Oquawka Il Visa Student Loan Perm Straight
# 2                                    General Dentist
# 3                                            Dentist
# 4                                            Dentist
# ...                                              ...
# 3028                                         Dentist
# ...

# %%
# dentist_job_cafe_df = df[df["source"] == "Dentist Job Cafe"]
# dental_post_df = df[df["source"] == "Dental Post"]

new_df = pd.DataFrame(columns=df.columns)

# dentist_job_cafe_df.to_sql('source_dentist_job_cafe', engine, if_exists='replace', index=False)
new_df.to_sql('source_ada_careercenter', engine, if_exists='replace', index=False)
# Out:
# 0

# %%
import pandas as pd
from datetime import datetime
from sqlalchemy import create_engine, text
engine = create_engine('postgresql://postgres:postgres@199.241.139.206:5431/dental_jobs')

dentist_job_cafe_df = pd.read_sql_query('select * from source_dentist_job_cafe',con=engine)
dental_post_df = pd.read_sql_query('select * from source_dental_post',con=engine)
dental_post_df
# Out:
#                                    job_id                  location  \
# 0    b53c7d0c-daed-3db1-a99d-edaa0607c0c6        Mckinney, TX 75070
# 1    510ff360-4147-3d99-a85b-fe42b0dd1e09      Richardson, TX 75080
# 2    eaf798f0-0fae-391f-bded-6b4a3b00ae63         Clayton, GA 30525
# 3    ab0a2d0c-ce22-33ab-bddc-5ae3c62b17c9  San Bernardino, CA 92410
# 4    5dd20764-ba0b-393b-ae7d-975ef27f5846          Smyrna, GA 30080
# ..                                    ...                       ...
# 862  d64bf846-ca17-35b6-be07-5252862ba539         Sedalia, MO 65301
# 863  fb318cea-2061-3ea2-8af7-14a1e1263d37         Durango, CO 81301
# 864  78cab968-570c-39ac-8645-55ed0e8f5294          Lawton, OK 73505
# 865  7952c8d3-6f41-39c7-8844-63f37d169a4f            Rome, GA 30165
# 866  48be5b2a-0c5a-3552-95d2-d265c157001c         Sherman, TX 75090
#
#           state date_posted                          employer employer_type  \
# ...

# %% [markdown]
# # Set up a new database table

# %%
import pandas as pd
from datetime import datetime
from sqlalchemy import create_engine, text
engine = create_engine('postgresql://postgres:postgres@199.241.139.206:5431/dental_jobs')

df = pd.DataFrame(columns=["key_word", "word_mapping"])
mapping = {"general dent": "General Dentist", 
           "pediatr": "Pediatric Dentist", 
           "exodont": "Exodontist", 
           "orthodon": "Orthodontist", 
           "associate dent": "Associate Dentist", 
           "endodon": "Endodontist",
           "locum": "Locum Dentist",
           "hygienist": "Dental Hygienist",
           "clinical director": "Clinical Director",
           "anesthesi": "Dental Anesthesiologist",
           "assistant": "Dental Assistant",
           "oms": "Oral Surgeon",
           "oral surgeon": "Oral Surgeon",
           "peridon": "Periodontist"}

df["key_word"] = mapping.keys()
df["word_mapping"] = mapping.values()
df.to_sql('job_title_mapping', engine, if_exists='replace', index=False)
# Out:
# 14

# %%
import pandas as pd
from datetime import datetime
from sqlalchemy import create_engine, text
engine = create_engine('postgresql://postgres:postgres@199.241.139.206:5431/dental_jobs')

# sql = "select * from job_title_mapping"
# df = pd.read_sql_query(sql,con=engine)
df = pd.DataFrame(columns=["org_name", "tag"])
df.to_sql('dso_mapping', schema="dental_mapping", con=engine, if_exists='replace', index=False)
# Out:
# 0

# %%
import pandas as pd
from datetime import datetime
from sqlalchemy import create_engine, text
engine = create_engine('postgresql://postgres:postgres@199.241.139.206:5431/dental_jobs')

# dentist_job_cafe_df = pd.read_sql_query('select * from source_dentist_job_cafe',con=engine)
# dental_post_df = pd.read_sql_query('select * from source_dental_post',con=engine)
# ada_df = pd.read_sql_query('select * from source_ada_careercenter',con=engine)
# dos_mapping = pd.read_sql_query('select * from dental_mapping.dso_mapping',con=engine)
df = pd.DataFrame(columns=['job_id', 'job_title', 'location', 'state', 'date_posted', 'employer',
       'employer_type', 'job_type', 'days_of_week', 'description', 'post_link',
       'source', 'created_at', 'latitude', 'longitude', 'actual_address', 'phone_number', 'website', 'email_address'])
df.to_sql('source_private_practices', engine, schema="source", if_exists='replace', index=False)
# Out:
# 0

# %%
# dentist_job_cafe_df["employer_type"] = dentist_job_cafe_df["employer"].apply(lambda x: generate_dso_mapping(x))
# dental_post_df["employer_type"] = dental_post_df["employer"].apply(lambda x: generate_dso_mapping(x))
# ada_df["employer_type"] = ada_df["employer"].apply(lambda x: generate_dso_mapping(x))

dentist_job_cafe_df.to_sql('source_dentist_job_cafe', engine, if_exists='replace', index=False)
dental_post_df.to_sql('source_dental_post', engine, if_exists='replace', index=False)
ada_df.to_sql('source_ada_careercenter', engine, if_exists='replace', index=False)
# Out:
# 807

# %%
dentist_job_cafe_sql = """
            ALTER TABLE source_dentist_job_cafe ADD CONSTRAINT dentist_job_cafe_pkey PRIMARY KEY (job_id);"""

dental_post_sql = """
            ALTER TABLE source_dental_post ADD CONSTRAINT dental_post_pkey PRIMARY KEY (job_id);"""

ada_sql = """
            ALTER TABLE source_ada_careercenter ADD CONSTRAINT ada_careercenter_pkey PRIMARY KEY (job_id);"""

with engine.connect() as conn:
    conn.execute(text(dentist_job_cafe_sql))
    conn.execute(text(dental_post_sql))
    conn.execute(text(ada_sql))
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1900, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1899     if not evt_handled:
# -> 1900         self.dialect.do_execute(
#    1901             cursor, statement, parameters, context
#    1902         )
#    1904 if self._has_events or self.engine._has_events:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py:736, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     735 def do_execute(self, cursor, statement, parameters, context=None):
# --> 736     cursor.execute(statement, parameters)
#
# UniqueViolation: could not create unique index "dentist_job_cafe_pkey"
# ...
