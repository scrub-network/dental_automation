# %%
import pandas as pd
from datetime import datetime
from sqlalchemy import create_engine, text
engine = create_engine('postgresql://postgres:postgres@199.241.139.206:5431/dental_jobs')
df = pd.read_sql_query('select * from job_postings',con=engine)

# %%
# Remove duplicates using the job_title, employer, and location
df.drop_duplicates(subset=['job_title', 'employer', 'location'], inplace=True)

# %%
df
# Out:
#                                     job_id                          job_title  \
# 0     fd238457-fb82-3ddd-965d-1ef20b5a34e4                            Dentist
# 1     35b929fe-79d1-34eb-b0eb-6194f68dc6c5                            Dentist
# 2     80c669ff-32c1-3070-a955-3d0245e956ac                            Dentist
# 3     8de0f9d5-ed10-30ae-9405-9e4b17cb5f2d                            Dentist
# 4     8eac5ab0-f72d-3a86-860a-05993784be24                            Dentist
# ...                                    ...                                ...
# 7793  c7f4e229-8ef1-3fa2-8906-4797ff52cb8c  General Dentist,Associate Dentist
# 7794  88d3e60a-e053-3216-a6b5-1e796ce4ab19                    General Dentist
# 7795  7b7b2450-b3b1-3e05-91d5-8ab9dd3a4582  General Dentist,Associate Dentist
# 7796  d720c3ed-eec0-3403-aacd-7fba3b11592c  General Dentist,Associate Dentist
# 7801  f248da53-a97c-3ff2-91cf-a681664f43d4  General Dentist,Associate Dentist
#
#                                   location          state date_posted  \
# 0         Herndon, Virginia, United States       Virginia  2023-11-07
# 1                        Atlanta, GA 30345        Georgia  2023-11-07
# 2                    San Antonio, TX 78240          Texas  2023-11-07
# 3                         Austin, TX 78703          Texas  2023-11-07
# 4     San Diego, California, United States     California  2023-11-07
# ...                                    ...            ...         ...
# 7793                    Bristol County, MA  Massachusetts  2022-12-22
# 7794                           St. Francis           None  2022-11-14
# 7795                          Annville, PA   Pennsylvania        None
# 7796                     Avon, Connecticut    Connecticut        None
# 7801                   Burlington, Vermont        Vermont        None
#
#                                       employer    employer_type  \
# 0                                 Smile Brands              DSO
# 1                         Dr. Wesley D. Powell        Undefined
# 2                   Cosmetic Dental Associates        Undefined
# 3            BLVD Dentistry & Orthodontic (AI)        Undefined
# 4                                 Smile Brands              DSO
# ...                                        ...              ...
# 7793  Henry Schein Dental Recruitment Services  Recruiting Firm
# 7794         St. Francis Mission Dental Clinic        Undefined
# 7795                         The Dentist Agent  Recruiting Firm
# 7796                         The Dentist Agent  Recruiting Firm
# 7801                         The Dentist Agent  Recruiting Firm
#
#                  job_type              days_of_week  \
# 0     Permanent/Full-Time
# 1               Permanent             Mon, Tue, Wed
# 2               Permanent  Mon, Tue, Wed, Thur, Fri
# 3               Permanent              Not Provided
# 4     Permanent/Full-Time
# ...                   ...                       ...
# 7793            Full Time                      None
# 7794            Full Time                      None
# 7795            Full Time                      None
# 7796            Full Time                      None
# 7801            Full Time                      None
#
#                                             description  \
# 0     Average SBI Provider earns $300,000-$400,000 a...
# 1     Seeking an associate doctor to join our privat...
# 2     Associate Dentist Job Opening and#64; Cosmetic...
# 3     BLVD Dentistry andamp; Orthodontics â 5th St...
# 4     Join a team on a mission to deliver smiles:   ...
# ...                                                 ...
# 7793                                          Undefined
# 7794                                          Undefined
# 7795  A well established, private practice in Annvil...
# 7796  Well established, group practice based in Conn...
# 7801  A well established, highly regarded private pr...
#
#                                               post_link            source  \
# 0     https://www.dentistjobcafe.com/job/dentist/gen...  Dentist Job Cafe
# 1     https://www.dentalpost.net/dental-jobs/job-pos...       Dental Post
# 2     https://www.dentalpost.net/dental-jobs/job-pos...       Dental Post
# 3     https://www.dentalpost.net/dental-jobs/job-pos...       Dental Post
# 4     https://www.dentistjobcafe.com/job/dentist/gen...  Dentist Job Cafe
# ...                                                 ...               ...
# 7793  https://careercenter.ada.org/job/131003/associ...               ADA
# 7794  https://careercenter.ada.org/job/103897/dental...               ADA
# 7795  https://careercenter.ada.org/job/169955/genera...               ADA
# 7796  https://careercenter.ada.org/job/169953/genera...               ADA
# 7801  https://careercenter.ada.org/job/169954/genera...               ADA
#
#                created_at
# 0     2023-11-07 20:17:41
# 1     2023-11-07 20:15:38
# 2     2023-11-07 20:15:34
# 3     2023-11-07 20:15:32
# 4     2023-11-07 20:23:48
# ...                   ...
# 7793  2023-10-23 14:54:28
# 7794  2023-10-23 15:21:27
# 7795  2023-11-07 20:31:42
# 7796  2023-11-07 20:31:43
# 7801  2023-11-07 20:31:46
#
# [5236 rows x 13 columns]
