# %%
from apify_client import ApifyClient

# Initialize the ApifyClient with your API token
api_token = 'apify_api_UO41ypIpxqPCckJ7ToeLAbATmmeqgg1xmrcv'
client = ApifyClient(api_token)

# Prepare the Actor input
run_input = {
    "action": "scrapeJobs",
    "scrapeJobs.searchUrl": "https://www.indeed.com/jobs?q=general%20dentist&l=New%20York%2C%20NY",
    "scrapeJobs.scrapeCompany": True,
    "startPage": 1,
    "count": 10,
    "proxy": {
        "useApifyProxy": True,
        "apifyProxyGroups": ["RESIDENTIAL"],
        "apifyProxyCountry": "US",
    },
}

# Run the Actor and wait for it to finish
run = client.actor("qA8rz8tR61HdkfTBL").call(run_input=run_input)

# Fetch and print Actor results from the run's dataset (if there are any)
for item in client.dataset(run["defaultDatasetId"]).iterate_items():
    print(item)
# Out:
# {'company': 'MUJI U.S.A. LIMITED', 'viewJobLink': '/viewjob?jk=21367ddfa0db4d1d&from=vjs&tk=1hc5c1p0lia1n800&viewtype=embedded&advn=8294604092588337&adid=418943776&ad=-6NYlbfkN0DnTYFJ6Ii0slDlES1ekMI9D77N-9agnctKGlt4t8spabwcqNRNavzySMtGmU4nmhKP34dGLvXW9OobYgirs4ME9U_MMxSW9YeZM4sfdWix-94LTnl5C-farqfZD7juyGLV0v4s2zS7DCJXAnFD5uqT6mJXmPCvC8xpuZRN1DIlUDR_Ncjs-s_dG2Crzxvfduksf3BtH6-Aym-_rmifW_RMJoI7twfv6YoPRz0JXGw3qJEMPuPqM3HUKfe6qtm7j1u9yHAFUd_rx960FzTJQov9qZ1mUp0LA-fVroTcqWtjTBJOGmmGauSSfQYZc44yqziMHt5cW3VwFmo1LgnfqqPuzct86YDSY2RmUY-TnOXbg4aaS12DCf81tb7MqS6VKhxOTQeM9dGz16_z6Hf4SshlaWAUEky5f_6U1vhWo1OTAoQxhgkVRrVnflG5ZxuVg97SC4MNGRtwzVPNl3v6jnNJq7pwmBHCLhGakDkO8NMLjgYFjxTQewABlpPQtRsA1TBzarqno0GY8rWG6lembCBdIY6n918dAyBhv3AqsG6tEU7SFETOITESUytg36uot7wWFy3SAIoVJYW1-f2XnC82abHyeU-PxIA%3D&xkcb=SoAT-_M3JFQI_4xd0B0LbzkdCdPP&continueUrl=%2Fjobs%3Fq%3Dsales%2Bassociate%2Bpart%2Btime%26vjk%3Db28e7b80d0399215%26l%3DNew%2BYork%252C%2BNY', 'companyBrandingAttributes': {'logoUrl': 'https://d2q79iu7y748
# ...
